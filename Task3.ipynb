# %% [markdown]
# <a href="https://colab.research.google.com/github/varunsuresh07/innomatics-internship/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#problem 1
employees = {
"Ravi": 92,
"Anita": 88,
"Kiran": 92,
"Suresh": 85
}
s=max(employees.values())
for name,emp in employees.items():
  if s==emp:
    print("Top performers eligible for bonus:",name,emp)
# Out:
# Top performers eligible for bonus: Ravi 92
# Top performers eligible for bonus: Kiran 92

# %%
#problem 2
s="Buy mobile phone buy phone online"
o=s.lower()
x=o.split()
l=['buy','phone']
dic={}
for i in x:
  if i in l:
    if i in dic:
      dic[i]+=1
    else:
      dic[i]=1
print(dic)
# Out:
# {'buy': 2, 'phone': 2}

# %%
#Problem 3
s= [3, 4, 7, 8, 10, 12, 5]
p=[]
for i in s:
  if i%2==0:
    p.append((s.index(i),i))
print(p)
# Out:
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %%
#problem 4
emails = [
"ravi@gmail.com",
"anita@yahoo.com",
"kiran@gmail.com",
"suresh@gmail.com",
"meena@yahoo.com"
]
dic={}
for i in emails:
  p=i.split("@")
  if p not in dic:
    dic[p]+=1
  else:
    dic[p]=1
# Out:
# gmail.com 60.0 %
# yahoo.com 40.0 %

# %%
#problem 5
sales = [1200, 1500, 900, 2200, 1400, 3000]
avg=sum(sales)/len(sales)
surge=avg+(0.3*avg)
for i in sales:
  if i>surge:
    print(f"day{sales.index(i)+1}:{i}")
#day 4 wont be included because it isnt more than the surge
# Out:
# day6:3000

# %%
#problem 6
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
dic={}
for i in user_ids:
  if i in dic:
    dic[i]+=1
  else:
    dic[i]=1
for c,j in dic.items():
  if j>1:
    print(f"{c}-->{j} times")
# Out:
# user1-->3 times
# user3-->2 times
